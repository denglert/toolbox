# %%
import os
setup_script = os.path.join(os.environ['ENV_JUPYTER_SETUPS_DIR'], 'setup_sci_env_basic.py')
# %run $setup_script
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib_utils.plot_func as plu

# %%
def saddle(x,y):
    return x**2 - y**2

# %%
x = np.linspace(-10.0, 10.0, 10)
y = np.linspace(-10.0, 10.0, 10)

# %%
X,Y = np.meshgrid(x,y)

# %%
X_flat = X.flatten()
Y_flat = Y.flatten()

# %%
Z = saddle(X,Y)
Z_flat = Z.flatten()

# %%
df = pd.DataFrame({'x':X_flat, 'y':Y_flat, 'z':Z_flat})

# %%
plu.pandas_contour(df, 'x', 'y', 'z', interp='linear')
# Out:
# (<matplotlib.figure.Figure at 0x7f45cf685940>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f45c79e0390>)

# %%
plu.pandas_contour(df, 'x', 'y', 'z', interp='cubic')
# Out:
# (<matplotlib.figure.Figure at 0x7f45c80d4b00>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f45c540e710>)
